# %%
pip install pymongoarrow
# Out:
# ...
#
# ...

# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: pymongo 4.8.0 does not provide the extra 'srv'

# %%
from pymongo import MongoClient
Client = MongoClient('mongodb://stage_pfa_24:PfA2024@217.182.139.190:29019/wepos_dup_db')
db = Client['wepos_dup_db']

# %%
import pandas as pd

client_df = pd.DataFrame(list(db.Client.find()))
client_df
# Out:
#                   _id first_name   last_name   age                     email  \
# 0    1JkEKSruxaVI6EGd      Salma          EL  32.0           salma@gmail.com
# 1    fOXi31L9VnBtLrVE      Salma          EL  22.0        salma.el@gmail.com
# 2    MmDrHGy1IxQ1pQYx     atlagh       Jihaf  25.0   youssoufabbo@gmail.com
# 3    HPuO7DOa9zyzhNZS    labbari     yassine  32.0  youssleouf_2001@yahoo.fr
# 4    r9KwVIlDCI60oAOm     mouad   bouhchouch  42.0          mourad@gmail.com
# ..                ...        ...         ...   ...                       ...
# 220  bxt3wF6XviZFjkTr       reem     albater  30.0            reem@gmail.com
# 221  4SkNMnvr0TUOHWcG       amal       mabar  35.0            amal@gmail.com
# 222  5hCdyFcYMifCw6t6       sara       kamar  35.0            sara@gmail.com
# 223  cIHIpuHaYL2mPAXt    ghizlan         usa  42.0         ghizlan@gmail.com
# 224  aE5N5Ot81DXm3G1E      sofia        twil  35.0           sofia@gmail.com
#
# ...

# %%
user_df=pd.DataFrame(list(db['_User'].find()))
user_df
# Out:
#                  _id                       username  \
# 0   DR7Lgsb1D57t3DgF                    aaaa@gm.com
# 1   p3vL0GBE2KalCoyr                  abc@gmail.com
# 2   WXJWCEAV0Du3Gmjc      jihad.aatlagh.1@gmail.com
# 3   4EQDuCpjy8ycNlvZ       jihad.atlagh.1@gmail.com
# 4   V4aldvlRoui8oGnt     yassine.baggar96@gmail.com
# ..               ...                            ...
# 81  X4f53ZU1LLkgmPSa  dr.loubna.elharrar@glowdoc.ma
# 82  qXUE2JRkeLi4KBRA  dr.cheymae.saadani@glowdoc.ma
# 83  j0TJmeywkk7HMznH  dr.mounia.lassouad@glowdoc.ma
# 84  GpAJhVz3Kathb1rL   dr.tarik.mahloute@glowdoc.ma
# 85  Nf5zFE6sdNz58X9o     dr.ahmed.walid@glowdoc.com
#
#                             email                                name  \
# 0                     aaaa@gm.com                                 aaa
# 1                   abc@gmail.com                                  aa
# 2       jihad.aatlagh.1@gmail.com                            jihad at
# ...

# %%
sale_df=pd.DataFrame(list(db.Sale.find()))
sale_df
# Out:
#                   _id payment_channel date_deposit comment  \
# 0    ygaMzDpEiznSougR            Cash   07-05-2024
# 1    y9VpExhIzQ6SNH3c            Cash   07-05-2024
# 2    G3PUhzXEfMXE4P98            Cash   07-05-2024
# 3    bAi6HxziCUH6dnCv            Cash   07-05-2024
# 4    isCgjl2YRAxAsrXO             TPE   01-07-2024
# ..                ...             ...          ...     ...
# 241  UgRQgzMdLbTl4Tw6             TPE         None
# 242  gtE4j5MT4bkdQpO7            Cash         None
# 243  KW0xOreLAy2LtrY1          Chèque         None
# 244  ezMDhxsAtlCaniu6            Cash   12-08-2024     NaN
# 245  MxgKwXZOeMspIuDF            Cash   12-08-2024     NaN
#
#                     _p_user                _p_client  total  \
# 0    _User$CAuPQAoDjvxDta0p  Client$fOXi31L9VnBtLrVE    600
# 1    _User$CAuPQAoDjvxDta0p  Client$fOXi31L9VnBtLrVE    600
# 2    _User$CAuPQAoDjvxDta0p  Client$fOXi31L9VnBtLrVE    700
# 3    _User$CAuPQAoDjvxDta0p  Client$fOXi31L9VnBtLrVE    700
# ...

# %%
product_df=pd.DataFrame(list(db.Product.find()))
product_df
# Out:
#                   _id                           name  price active  \
# 0    ud3VbKosfuhyjMN6                      product A  100.0   True
# 1    Uf8CSvMfLixLSDc1                      Product 2  200.0   True
# 2    SBaOuahqpvKwtpKS  Lotion Apaisante Intense 50ml    NaN   True
# 3    CFERLCsD0gfkY3d6                           test  100.0   True
# 4    o7CHBal7k8ptmSbQ  Lotion Apaisante Intense 50ml    NaN  False
# ..                ...                            ...    ...    ...
# 125  phOcEQpzuG4LRyI2                         test 1  450.0   True
# 126  rQH9Ko9Yo3vfLXT3                         test 2  400.0   True
# 127  jUn3r5tUpvtMXyOX                  addProd test   120.0    NaN
# 128  6wpaUBSwlRuC9bAL                  add Prod test  230.0    NaN
# 129  x8eAIKjjOnk8fk0m                add prod test 2  200.0    NaN
#
#                                               pictures  \
# 0    [f0688c9b13e8557f15e397157a883f65_4b2bc2f9-f20...
# ...

# %%
service_df= pd.DataFrame(list(db.Service.find()))
service_df
# Out:
#                   _id                                           pictures  \
# 0    MQxhVyNAaYKOpIhv  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 1    ed86v7G2B57Y7NMu  [7d300104752e0887b8e4cba855c04af4_70e13299-47d...
# 2    4PGv6LBatj0y303i  [37635cb7f43967f6545c4f8a0237132c_a45e9020-49e...
# 3    6FvHw23U9BHS1tOL                                                 []
# 4    fAHoBGq9JEvNBdF8  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# ..                ...                                                ...
# 462  sdC0wyBaPfwLqFYJ      [e590e879b4c10c68c66f969887bc3433_botox.jpeg]
# 463  cerXAqNoUCXVlb2l  [18a790522a03eeaff8735bd7484131c5_microneedlin...
# 464  EYQDD56ivYQE54aw  [590fd7c564943b55d12ae95803b66dcd_medecine-est...
# 465  klAfmcfECoHV3bjq                                                 []
# 466  0uTFeZdVIHJh8ojY                                                 []
#
#                                           sub_services  \
# ...

# %%
purchase_df = pd.DataFrame(list(db.Purchase.find()))
purchase_df
# Out:
#                  _id                                           products  \
# 0   5P8y1B2yVGdhQ7Ui                                                 []
# 1   VlxjoliEBbyKkvDd  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 2   r05v0SZMOw6qouVI  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 3   bW7ZGez05Zx0iCvu  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 4   Z05PMKi6Y4sqHbK6  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 5   b0d2kYZTHg2HA0uy  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 6   HrgCUwOB1SrdrIcR  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 7   sBKu2ekP3mpUPIm9  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 8   XUL0z6gCRKKSqVRu  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 9   pf3jtPGuFOqcrXwM  [{'name': 'hard', 'price': '500.0', 'photo': '...
# 10  B85L0ZJ8wjN18Ui8  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# 11  wZmHc5e1ojNCXMdC  [{'name': 'Lotion Apaisante Intense 50ml', 'pr...
# ...

# %%
zone_df = pd.DataFrame(list(db.Zone.find()))
zone_df
# Out:
#                 _id                name             _created_at  \
# 0  jXmgFbeZ33pMtWjD             Cheveux 2024-04-28 20:44:20.455
# 1  BnYnnL4DxRnLiOly          Visage/cou 2024-04-28 20:44:38.111
# 2  DHs1T89GhLgYgoWF  Corps / Silhouette 2024-04-28 20:44:50.766
# 3  fUDhUtI4YImsD7gD                Peau 2024-04-28 20:44:59.848
# 4  8kSNtDvDhCEF9hxd               Mains 2024-04-28 20:45:08.958
# 5  4Ty59voMYfClsTnr       Zones intimes 2024-04-28 20:45:19.710
#
#               _updated_at description  \
# 0 2024-07-03 10:06:37.446
# 1 2024-07-03 10:06:37.446
# 2 2024-07-03 08:54:41.852
# 3 2024-07-02 18:09:38.744
# 4 2024-06-29 02:11:19.493
# 5 2024-05-06 16:50:48.694
#
#                                                 logo
# 0       a4003b5ee9ec1d40fc0fa3301387106f_cheveux.jpg
# 1  8e2be227e1eeaeb799a8c4c6a7b76085_1-Screenshot_...
# 2  9ad2c502586b53b550809c39ca5923d7_3-Screenshot_...
# 3  5587ae32ef211e5eba01796ccd0b99a9_8-Screenshot_...
# ...

# %%
appointment_df = pd.DataFrame(list(db.Appointment.find()))
appointment_df
# Out:
#                  _id                 _p_user             _created_at  \
# 0   eDYCkVBDDCJjA7qW  _User$K1YAxjwUjbh2p8JJ 2024-07-12 22:24:53.927
# 1   bdQI1DDWBILFspim  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:02:39.852
# 2   0MfDPlZkU9fb0L8T  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:03:47.952
# 3   FRcmHreK00RmAKhR  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:12:41.227
# 4   DhxFMPbbB4iBrfFH  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:13:41.215
# 5   ffjtRZZfVNYmV3Ps  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:14:38.464
# 6   WLZVD3PG7dmhq4pl  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:15:12.594
# 7   AKLx226b6BCtLs6h  _User$4EQDuCpjy8ycNlvZ 2024-07-15 09:38:37.749
# 8   XnNAyKqXvGPE76jl  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:50:31.726
# 9   TTDK4WAmbHR2iMCr  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:51:31.960
# 10  tZASKoSnuDJva65S  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:52:27.751
# 11  HGtVoOLEUpyBTSd7  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:59:58.614
# 12  d6TElGZpXOWNF5e9  _User$dgZAXyrqPg4tcbGn 2024-07-20 12:57:16.584
# ...

# %%
medicine_df = pd.DataFrame(list(db.Medicine.find()))
medicine_df
# Out:
#                 _id                                               name  \
# 0  krZMnLKrHpdelU1f                                  Doliprane 1000 mg
# 1  pNg73pVzt04VaRX8               CODOLIPRANE 400 MG / 20 MG, Comprimé
# 2  CmAeKmc7lwqGBo7U                           DOLIPRANE 500 MG, Sachet
# 3  29p1tlIprRyaUKoM  DOLIPRANE VITAMINE C 500 MG, Comprimé efferves...
#
#               _created_at             _updated_at
# 0 2024-05-05 01:04:21.533 2024-05-05 01:04:21.533
# 1 2024-05-05 10:42:58.673 2024-05-05 10:42:58.673
# 2 2024-05-05 10:43:49.081 2024-05-05 10:43:49.081
# 3 2024-05-05 10:44:11.281 2024-05-05 10:44:11.281

# %%
provider_df = pd.DataFrame(list(db.Provider.find()))
provider_df
# Out:
#                 _id       name             _created_at  \
# 0  xTFvoY6QXOJYgGiD  Ordinary5 2024-05-29 19:14:41.903
# 1  FME2G7wjnHW4iXHW  Ordinary4 2024-06-08 10:46:37.348
# 2  GJUj6DLHtCMJD4QF  Ordinary3 2024-06-08 10:54:41.209
# 3  Cc4C81CDy9XJvAlV   Ordinary 2024-06-08 10:54:49.528
# 4  PAoYy4RcMDksH1t1  Ordinary1 2024-06-08 10:54:49.528
# 5  G8dgVLpXfX46MepZ    renalia 2024-07-02 11:24:46.613
# 6  FdTrMAblVYxaxt8B        SMD 2024-07-29 10:35:47.469
#
#               _updated_at                                             logo  \
# 0 2024-06-08 10:59:31.560         34d8c91d6b7625e6156e279ca577c083_abc.png
# 1 2024-06-08 10:59:28.511         34d8c91d6b7625e6156e279ca577c083_abc.png
# 2 2024-06-08 10:59:25.022         34d8c91d6b7625e6156e279ca577c083_abc.png
# 3 2024-06-08 10:54:49.528         34d8c91d6b7625e6156e279ca577c083_abc.png
# 4 2024-06-08 10:59:19.185         34d8c91d6b7625e6156e279ca577c083_abc.png
# ...

# %%
publication_df= pd.DataFrame(list(db.Publication.find()))
publication_df
# Out:
#                  _id                 _p_user                          _wperm  \
# 0   ZsvyDqKpoh8FEkLZ  _User$7ZlcrixemNHDBvgF  [7ZlcrixemNHDBvgF, role:admin]
# 1   8bhI9apxCueHm2iJ  _User$7ZlcrixemNHDBvgF  [7ZlcrixemNHDBvgF, role:admin]
# 2   dwZYJEVLFqFt6NA1  _User$7ZlcrixemNHDBvgF  [7ZlcrixemNHDBvgF, role:admin]
# 3   vKEpTymDyryqZ7gO  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 4   g6H0GGDo7hzKydKT  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 5   WQ1mUVAFZhCOGCP4  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 6   SfqRBjyAT4xDvH16  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 7   l1yQx8azGfhD8sxj  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 8   OLrENdGJGQ7F6SwE  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 9   zGGFuMCvE85jHBOE  _User$4EQDuCpjy8ycNlvZ  [4EQDuCpjy8ycNlvZ, role:admin]
# 10  O8Zv8Bg2xJCl9AqZ  _User$78Y22jKzYbD0u8p3  [78Y22jKzYbD0u8p3, role:admin]
# ...

# %%
city_df= pd.DataFrame(list(db.City.find()))
city_df
# Out:
#                  _id        name             _created_at  \
# 0   YJEGF1rhmr55JjAV  Casablanca 2024-04-29 00:42:42.446
# 1   lSoE5IFGhhXoyN4h       Rabat 2024-04-29 00:42:47.606
# 2   QxVxMCQ1xbC01L0Q      Tanger 2024-04-29 00:42:52.976
# 3   KXIsQcI3ilPfB9h9   Marrakech 2024-04-29 00:43:00.559
# 4   JqiBLeQE2xwT5L40         Fes 2024-04-29 00:43:05.012
# 5   3GUYyNkvUm7tIJ79      Agadir 2024-04-29 00:43:10.079
# 6   CPYDg3KUGb3gFVL9       Oujda 2024-04-29 00:43:18.327
# 7   Hi9iD7DvI5wHRlmd     Kénitra 2024-04-29 00:43:29.169
# 8   B2qNpocsB1Wg1G7Y  Mohammedia 2024-04-29 00:43:38.825
# 9   VG9SSG2ebHXnitht      Temara 2024-04-29 00:43:44.370
# 10  DFPCxJOXRhb5cgG5   El jadida 2024-05-30 11:14:07.795
# 11  HheeSRSHbkjx23M3     Tetouan 2024-07-23 00:40:59.413
#
#                _updated_at  id
# 0  2024-06-25 10:27:43.636 NaN
# 1  2024-04-29 00:42:47.606 NaN
# 2  2024-04-29 00:42:52.976 NaN
# 3  2024-04-29 00:43:00.559 NaN
# 4  2024-04-29 00:43:05.012 NaN
# ...

# %%
subproduct_df = pd.DataFrame(list(db.SubProduct.find()))
subproduct_df
# Out:
#                   _id                           name   price active  \
# 0    bh7AG3wQZEvivKnt                sub-product 2.1   210.0   True
# 1    ae1NmCYnDmSj87CJ  Lotion Apaisante Intense 50ml   100.0  False
# 2    QEWva4ciQhgFw5ZU                sub-product a.1   100.0  False
# 3    fNmOhpVKzM3rIA5o                      sous name  1200.0   True
# 4    vPWIEhY915oDpMp9  Lotion Apaisante Intense 50ml     NaN  False
# ..                ...                            ...     ...    ...
# 126  ptFKLM9Sy7kYkzaj                        test 20   210.0    NaN
# 127  KfXUNb6DqfLpKaMU                        test 19    23.0    NaN
# 128  DkUngKJSeipY8uiY                        test 31    20.0    NaN
# 129  Vx5AdvHmXM9O1zHk                        test 77   120.0    NaN
# 130  JE8OGyDIARlsQgkE                     sub prod 1   100.0    NaN
#
#                     _p_user             _created_at             _updated_at  \
# ...

# %%
subservice_df = pd.DataFrame(list(db.SubService.find()))
subservice_df
# Out:
#                  _id                                           pictures  \
# 0   JtZCieAS8hgga6WL  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 1   msduB21BlKWuNmCq                                                 []
# 2   wPsbMhkgg6KJIYer                                                 []
# 3   ldIa5Bf2pozEf1yY  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 4   7Aio9Oq3ZLtfihBV  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# ..               ...                                                ...
# 69  PSc9Ph4GCHngJNPq  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 70  XyOzGrSEDkJadtjg  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 71  1Bdcg8dPF5TVwNA8  [3307d3bbd9d7bb279972ced4385fb3a8_peeling-char...
# 72  HreshBUKgb7Cf1DD                                                 []
# 73  lquE3ItUqpwxKCZl                                                 []
#
#                    _p_user                             name      description  \
# ...

# %%
appointment_df = pd.DataFrame(list(db.Appointment.find()))
appointment_df
# Out:
#                  _id                 _p_user             _created_at  \
# 0   eDYCkVBDDCJjA7qW  _User$K1YAxjwUjbh2p8JJ 2024-07-12 22:24:53.927
# 1   bdQI1DDWBILFspim  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:02:39.852
# 2   0MfDPlZkU9fb0L8T  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:03:47.952
# 3   FRcmHreK00RmAKhR  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:12:41.227
# 4   DhxFMPbbB4iBrfFH  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:13:41.215
# 5   ffjtRZZfVNYmV3Ps  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:14:38.464
# 6   WLZVD3PG7dmhq4pl  _User$K1YAxjwUjbh2p8JJ 2024-07-14 22:15:12.594
# 7   AKLx226b6BCtLs6h  _User$4EQDuCpjy8ycNlvZ 2024-07-15 09:38:37.749
# 8   XnNAyKqXvGPE76jl  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:50:31.726
# 9   TTDK4WAmbHR2iMCr  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:51:31.960
# 10  tZASKoSnuDJva65S  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:52:27.751
# 11  HGtVoOLEUpyBTSd7  _User$K1YAxjwUjbh2p8JJ 2024-07-15 17:59:58.614
# 12  d6TElGZpXOWNF5e9  _User$dgZAXyrqPg4tcbGn 2024-07-20 12:57:16.584
# ...

# %%
#filled null values with unknown, then the ones the incompatible types with NAN
client_df.fillna('NAN', inplace=True)
provider_df.fillna('NAN', inplace=True)
city_df.fillna('NAN', inplace=True)
appointment_df.fillna('NAN', inplace=True)
publication_df.fillna('NAN', inplace=True)
medicine_df.fillna('NAN', inplace=True)
purchase_df.fillna('NAN', inplace=True)
product_df.fillna('NAN', inplace=True)
user_df.fillna('NAN', inplace=True)
zone_df.fillna('NAN', inplace=True)
sale_df.fillna('NAN', inplace=True)
service_df.fillna('NAN', inplace=True)
subservice_df.fillna('NAN', inplace=True)
subproduct_df.fillna('NAN', inplace=True)
appointment_df.fillna('NAN', inplace=True)
# Out:
# C:\Users\rim-1\AppData\Local\Temp\ipykernel_3196\762463198.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NAN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   client_df.fillna('NAN', inplace=True)
# C:\Users\rim-1\AppData\Local\Temp\ipykernel_3196\762463198.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NAN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   city_df.fillna('NAN', inplace=True)
# C:\Users\rim-1\AppData\Local\Temp\ipykernel_3196\762463198.py:6: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NAN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   publication_df.fillna('NAN', inplace=True)
# ...

# %%
purchase_df.dtypes
# Out:
# _id                     object
# products                object
# documents               object
# _created_at     datetime64[ns]
# _updated_at     datetime64[ns]
# _p_user                 object
# _p_provider             object
# total                  float64
# dateDeposit             object
# date_deposit            object
# dtype: object

# %%
#the top providers
def transform_provider_id(provider_id):
    return provider_id.replace("Provider$", "")

purchase_df['_p_provider'] = purchase_df['_p_provider'].apply(transform_provider_id)

merged_df = purchase_df.merge(provider_df, left_on='_p_provider', right_on='_id', how='left')

# Group by provider_name and count occurrences
provider_purchase_count = merged_df.groupby('name').size().sort_values(ascending=False)

print(provider_purchase_count)
# Out:
# name
# Ordinary3    8
# Ordinary5    4
# Ordinary     3
# Ordinary1    3
# renalia      2
# Ordinary4    1
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
provider_purchase_count.plot(kind='bar', figsize=(7, 4), color='skyblue')
plt.title('The top providers')
plt.xlabel('Provider Name')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %%
#the most purchased products

#separating the products dict
separate_products=purchase_df.explode('products')
#dropping the products column since it contains dict and making each elementof the dict in a separate column
separate_products = pd.concat([separate_products.drop(['products'],axis=1), separate_products['products'].apply(pd.Series)],axis=1)

#Group by product name 
top_purchased_products = separate_products.groupby('name').size().sort_values(ascending=False)
top_purchased_products
# Out:
# name
# Lotion Apaisante Intense 50ml    14
# zzzzz                             3
# Crème anti ride                   2
# Crème exfoliante 100ml            2
# hard                              2
# EV                                1
# Serum skinceuticals               1
# aaaa                              1
# gp                                1
# hydro                             1
# dtype: int64

# %%
plt.figure(figsize=(7, 5))
top_purchased_products.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(top_purchased_products))))
plt.title('Top Purchased Products')
plt.ylabel('')  
plt.show()

# %%
#which gender is more into aesthetic procedures 
clients_by_gender = client_df.groupby('gender').size()
clients_by_gender
# Out:
# gender
# homme    225
# dtype: int64

# %%
plt.figure(figsize=(7, 5))
clients_by_gender.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired(range(len(top_purchased_products))))
plt.title('Clients that are into aesthetics more based on gender')
plt.ylabel('')  
plt.show()

# %%
#what do most clients do
from unidecode import unidecode
import re

def normalize_title(title):
    title = unidecode(title).strip().lower() 
    title = re.sub(r'\s+', '', title)  
    return title

# %%
client_df['title'] = client_df['title'].apply(normalize_title)
clients_by_title = client_df.groupby('title').size().sort_values(ascending=False)
clients_by_title
# Out:
# title
# x                     155
#                        12
# medecin                 3
# pharmacienne            3
# ingenieur               3
# masseuse                2
# salarie                 2
# employe                 2
# casa                    2
# aa                      1
# notaire                 1
# maitrsse                1
# maman                   1
# marchand                1
# mk                      1
# nan                     1
# pd                      1
# ostgropathe             1
# patientdetest           1
# petrole                 1
# prof                    1
# styliste                1
# tailleur                1
# tijaru                  1
# traiteur                1
# w                       1
# jgg                     1
# infirmierebadecasa      1
# aaaa                    1
# 11                      1
# actrice                 1
# autre                   1
# avocat                  1
# banque                  1
# businesswomen           1
# ...

# %%
# Group rare titles into 'other'
title_counts = clients_by_title[clients_by_title <= 2].index
client_df['title'] = client_df['title'].replace(title_counts, 'other')
client_df['title'] = client_df['title'].replace('', 'other')


# Recount the number of clients per title after grouping rare titles
clients_by_title = client_df.groupby('title').size().sort_values(ascending=False)
clients_by_title
# Out:
# title
# x               155
# other            61
# ingenieur         3
# medecin           3
# pharmacienne      3
# dtype: int64

# %%
plt.figure(figsize=(7, 5))
clients_by_title.plot(kind='barh', color='skyblue')
plt.title('what are the top titles our clients have?')
plt.xlabel('Number of Clients')
plt.ylabel('Client Title')
plt.grid(axis='x')
plt.show()

# %%
#Total Number of Sales for Each User
def transform_user_id(_p_user):
    return _p_user.replace("_User$", "")

# %%
sale_df['_p_user'] = sale_df['_p_user'].apply(transform_user_id)

# %%
merged_sale_df = sale_df.merge(user_df, left_on='_p_user', right_on='_id', how='left')

# %%
sales_per_user=merged_sale_df.groupby('name').size().sort_values(ascending=False)
sales_per_user
# Out:
# name
# Cabinet Docteur Oumnia    216
# Cabinet de test             8
# jiyaa                       6
# Pretty Perfection           4
# Beauty care Lab             2
# Cabinet Dermacost           2
# Pure Harmony                2
# dtype: int64

# %%
plt.figure(figsize=(7, 4))
sales_per_user.plot(kind='bar', color='skyblue')
plt.title('Total Number of Sales for Each User')
plt.xlabel('User Name')
plt.ylabel('Number of Sales')
plt.xticks(rotation=45)
plt.grid(axis='y')

# %%
sale_df.dtypes
# Out:
# _id                             object
# payment_channel                 object
# date_deposit                    object
# comment                         object
# _p_user                         object
# _p_client                       object
# total                            int64
# products                        object
# services                        object
# pictures                        object
# pictures_before                 object
# pictures_after                  object
# zones                           object
# _created_at             datetime64[ns]
# _updated_at             datetime64[ns]
# productsConsommables            object
# reduction                       object
# date                    datetime64[ns]
# date_reserve                    object
# payments                        object
# dtype: object

# %%
sale_df['date_deposit'] = pd.to_datetime(sale_df['date_deposit'], format='%d-%m-%Y', errors='coerce')

# %%
sale_df.set_index('date_deposit', inplace=True)

# %%
#avg sales per day
daily_sales = sale_df.resample('D').size()
avg_sales_per_day = daily_sales.mean()
print(f'Average sales per day: {avg_sales_per_day}')
# Out:
# Average sales per day: 2.8072289156626504

# %%
#avg sales per month
monthly_sales = sale_df.resample('M').size()
avg_sales_per_month = monthly_sales.mean()
print(f'Average sales per month: {avg_sales_per_month}')
# Out:
# Average sales per month: 77.66666666666667

# %%
#avg sales per year
yearly_sales = sale_df.resample('Y').size()
avg_sales_per_year = yearly_sales.mean()
print(f'Average sales per year: {avg_sales_per_year}')
# Out:
# Average sales per year: 233.0

# %%
fig, ax = plt.subplots(3, 1, figsize=(9, 7))

ax[0].plot(daily_sales.index, daily_sales, marker='o', linestyle='-')
ax[0].axhline(y=avg_sales_per_day, color='r', linestyle='--')
ax[0].set_title('Daily Sales')
ax[0].set_xlabel('Date')
ax[0].set_ylabel('Number of Sales')
ax[0].legend(['Daily Sales', f'Avg Sales Per Day: {avg_sales_per_day:.2f}'])

ax[1].plot(monthly_sales.index, monthly_sales, marker='o', linestyle='-')
ax[1].axhline(y=avg_sales_per_month, color='r', linestyle='--')
ax[1].set_title('Monthly Sales')
ax[1].set_xlabel('Month')
ax[1].set_ylabel('Number of Sales')
ax[1].legend(['Monthly Sales', f'Avg Sales Per Month: {avg_sales_per_month:.2f}'])

ax[2].plot(yearly_sales.index, yearly_sales, marker='o', linestyle='-')
ax[2].axhline(y=avg_sales_per_year, color='r', linestyle='--')
ax[2].set_title('Yearly Sales')
ax[2].set_xlabel('Year')
ax[2].set_ylabel('Number of Sales')
ax[2].legend(['Yearly Sales', f'Avg Sales Per Year: {avg_sales_per_year:.2f}'])


plt.tight_layout()
plt.show()

# %%
#The Most Bought Products
exploded_sales = sale_df.explode('products')
exploded_sales = pd.concat([exploded_sales.drop(['products'],axis=1), exploded_sales['products'].apply(pd.Series)],axis=1)

most_bought_products = exploded_sales.groupby('name').size().sort_values(ascending=False)
most_bought_products
# Out:
# name
# botox                            44
# EV                               36
# hydro                            18
# hard                             17
# Lotion Apaisante Intense 50ml    16
# harmyca                           6
# ultra4                            5
# Crème exfoliante 100ml            4
# Derma-ease                        4
# Sérum anti-âge                    2
# endolift                          2
# gp                                2
# pluriel                           2
# test                              2
# aaaa                              1
# exosome                           1
# dtype: int64

# %%
most_bought_products_filtered = most_bought_products[most_bought_products >= 3]
other_products_count = most_bought_products[most_bought_products < 3].sum()
# Append 'Other' category
most_bought_products_filtered['Other'] = other_products_count

most_bought_products_filtered = most_bought_products_filtered.sort_values(ascending=False)
most_bought_products_filtered
# Out:
# name
# botox                            44
# EV                               36
# hydro                            18
# hard                             17
# Lotion Apaisante Intense 50ml    16
# Other                            12
# harmyca                           6
# ultra4                            5
# Crème exfoliante 100ml            4
# Derma-ease                        4
# dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(7, 5))
sns.barplot(x=most_bought_products_filtered.index, y=most_bought_products_filtered.values, palette="viridis")

plt.xticks(rotation=90)
plt.xlabel('Product Name')
plt.ylabel('Number of Purchases')
plt.title('The Most Bought Products')
plt.show()

# %%
#city with the most users 
city_mapping = dict(zip(city_df['name'].str.lower(), city_df['_id']))

# %%
def map_address_to_city(address):
    if pd.isna(address):
        return "Casablanca"  # Assign Casablanca if address is NaN
    
    address_lower = address.lower()
    
    # Check if the address contains any known city name
    for city_name in city_mapping.keys():
        if city_name in address_lower:
            return city_name.capitalize()
    
    # If no city is found, assign Casablanca by default
    return "Casablanca"

# %%
#new column 'city' in user_df
user_df['city'] = user_df['address'].apply(map_address_to_city).replace("   ", 'Unknown')
print(user_df[['address', 'city']])
# Out:
#                                               address        city
# 0                                          Casablanca  Casablanca
# 1                                          Casablanca  Casablanca
# 2                                                      Casablanca
# 3   Capital Tower, Boulevard Moulay Abdellah Cheri...  Casablanca
# 4   184, Angle Avenue 2 Mars Et Boulevard El Fida,...  Casablanca
# ..                                                ...         ...
# 81  7 Rue Uruguay Tanger, 2 ème Etage Bureau N°8, ...      Tanger
# 82  40 Bd Med 5, Résidence Dounia, Etage 2, App 16...  Casablanca
# 83  140, avenue de fes, '' office fes street '' 5è...         Fes
# 84  39, Boulevard Moulay Ismail, Residence ZAHRA E...      Tanger
# 85  107, Av. Mohamed V (Nejma), Résidence Dos Mare...  Casablanca
#
# [86 rows x 2 columns]

# %%
#city with the most users 
city_estheticians = user_df.groupby('city').size().sort_values(ascending=False)
city_estheticians
# Out:
# city
# Casablanca    65
# Rabat         10
# Marrakech      7
# Tanger         2
# Fes            1
# Tetouan        1
# dtype: int64

# %%
plt.figure(figsize=(7, 5))
sns.barplot(x=city_estheticians.values, y=city_estheticians.index, palette="magma")

plt.xlabel('Number of Users')
plt.ylabel('City')
plt.title('City with the Most Users')
plt.show()

# %%
appointment_df['_p_client_id'] = appointment_df['_p_client'].str.split('$').str[1]

merged_df = pd.merge(appointment_df, client_df, left_on='_p_client_id', right_on='_id', how='left')

# Drop unnecessary columns if needed
merged_df = merged_df.drop(columns=['_p_client', '_p_client_id'])  # Adjust based on your needs
# Group by client name and count the number of appointments
appointments_per_client = merged_df.groupby(['first_name', 'last_name']).size().reset_index(name='appointment_count')


print("\nAppointments Per Client:")
print(appointments_per_client.head())
# Out:
# Appointments Per Client:
#   first_name    last_name  appointment_count
# 0    Othmane  Ait jillali                  4
# 1      Salma           EL                  2
# 2   Soufiane  AIT JILLALI                  1
# 3    Yassine       Baggar                  4
# 4         at           at                  3

# %%
clients = appointments_per_client['first_name'] + ' ' + appointments_per_client['last_name']
appointment_counts = appointments_per_client['appointment_count']

# Plotting
plt.figure(figsize=(7, 6))
plt.bar(clients, appointment_counts, color='skyblue')
plt.xlabel('Client')
plt.ylabel('Number of Appointments')
plt.title('Number of Appointments Booked per Client')
plt.xticks(rotation=45, ha='right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
#services les plus demandés par les clients d'apres sale
separate_services = sale_df.explode('services')

separate_services = pd.concat([separate_services.drop(['services'], axis=1), separate_services['services'].apply(pd.Series)], axis=1)

service_demand_count = separate_services.groupby('name').size().sort_values(ascending=False)
service_demand_count
# Out:
# name
# Filler                              111
# Botox                                86
# Skin booster                         29
# Peeling laser au carbone             11
# Injections botox                     10
# Laser Co2                            10
# meso                                  6
# Endolift                              6
# cernes                                5
# Soins de visage                       5
# consultation                          4
# service de test                       4
# PEELINGS                              4
# LASER                                 4
# Transpiration excessive               2
# endolift                              2
# Radiofréquence à micro-aiguilles      2
# dtype: int64

# %%
plt.figure(figsize=(7, 5))

sns.barplot(x=service_demand_count.values, y=service_demand_count.index, palette="plasma")
plt.xlabel('Number of Demands')
plt.ylabel('Service Name')
plt.title('Most Demanded Services by Clients')
plt.show()

# %%
exploded_df = product_df.explode('sub_products')
exploded_df = pd.concat([exploded_df.drop(['sub_products'], axis=1), exploded_df['sub_products'].apply(pd.Series)], axis=1)

merged_df = pd.merge(exploded_df, subproduct_df, how='left', left_on='objectId', right_on='_id')

#we Fill NaN prices from subproducts with the original product price
merged_df['final_price'] = merged_df.apply(lambda row: row['price_y'] if not pd.isna(row['price_y']) else row['price_x'], axis=1)

merged_df['final_price'] = pd.to_numeric(merged_df['final_price'], errors='coerce')

#we Drop rows where final_price could not be converted to numeric
merged_df = merged_df.dropna(subset=['final_price'])
merged_df['final_price']
# Out:
# 0       100.0
# 1       210.0
# 2       100.0
# 3       100.0
# 5         0.0
# 7         0.0
# 19        0.0
# 20        0.0
# 23        0.0
# 24        0.0
# 26        0.0
# 27        0.0
# 28        0.0
# 29        0.0
# 30      200.0
# 31      400.0
# 32        0.0
# 33      200.0
# 34      200.0
# 35      250.0
# 36      100.0
# 37      200.0
# 38      150.0
# 39      300.0
# 40      200.0
# 45     1800.0
# 46     3500.0
# 48      400.0
# 49      400.0
# 50      380.0
# 51      400.0
# 53      999.0
# 54      222.0
# 55      122.0
# 56      122.0
# 70     2000.0
# 124     200.0
# 125     200.0
# 126     100.0
# 127     100.0
# 128     100.0
# 129     160.0
# 130     200.0
# 131     210.0
# 132      23.0
# 133     230.0
# 134     120.0
# Name: final_price, dtype: float64

# %%
#avg price fro a product
average_price_product = merged_df['final_price'].mean()
print(f'Average price of a product: {average_price_product} DH')
# Out:
# Average price of a product: 312.72340425531917 DH

# %%
exploded_df = service_df.explode('sub_services')
exploded_df = pd.concat([exploded_df.drop(['sub_services'], axis=1), exploded_df['sub_services'].apply(pd.Series)], axis=1)

merged_df = pd.merge(exploded_df, subservice_df, how='left', left_on='objectId', right_on='_id')

merged_df['final_price'] = merged_df.apply(lambda row: row['price_y'] if not pd.isna(row['price_y']) else row['price_x'], axis=1)

# Convert final_price to numeric
merged_df['final_price'] = pd.to_numeric(merged_df['final_price'], errors='coerce')

# Drop rows where final_price could not be converted to numeric
merged_df = merged_df.dropna(subset=['final_price'])
merged_df['final_price']
# Out:
# 1       200.0
# 2       200.0
# 3       300.0
# 4       600.0
# 20     2000.0
# 21     2000.0
# 22     2000.0
# 23     2000.0
# 24     2000.0
# 25     2000.0
# 26     2000.0
# 27     4000.0
# 48     1000.0
# 49      800.0
# 65      120.0
# 66     2200.0
# 67     1100.0
# 68      600.0
# 69      300.0
# 70      600.0
# 71      600.0
# 72      800.0
# 73      400.0
# 74     1000.0
# 75      600.0
# 76      700.0
# 77      800.0
# 78      900.0
# 79     1000.0
# 80      600.0
# 81     2000.0
# 82     2000.0
# 83     6000.0
# 84     2000.0
# 100     500.0
# 101    1500.0
# 106     200.0
# 107     500.0
# 118     200.0
# 139    3500.0
# 140    3500.0
# 146     750.0
# 147    1500.0
# 148     100.0
# 149    1500.0
# 150    1500.0
# 156      12.0
# 157    1111.0
# 488     400.0
# 489     400.0
# 490     500.0
# Name: final_price, dtype: float64

# %%
#avg price for a service 
average_price_service = merged_df['final_price'].mean()
print(f'Average price of a service: {average_price_service} DH')
# Out:
# Average price of a service: 1237.1176470588234 DH

# %%
plt.figure(figsize=(7, 5))
plt.bar(['Product', 'Service'], [average_price_product, average_price_service], color=['blue', 'green'])
plt.title('Average Price Comparison')
plt.ylabel('Price (DH)')
plt.show()

# %%
merged_df['final_time'] = merged_df.apply(lambda row: row['time_y'] if not pd.isna(row['time_y']) else row['time_x'], axis=1)

# Convert final_price to numeric
merged_df['final_time'] = pd.to_numeric(merged_df['final_time'], errors='coerce')

# Drop rows where final_price could not be converted to numeric
merged_df = merged_df.dropna(subset=['final_time'])
merged_df['final_time']
# Out:
# 1        20.0
# 2        20.0
# 3        30.0
# 4        20.0
# 20       30.0
# 21       25.0
# 22       25.0
# 23       22.0
# 24       25.0
# 25       30.0
# 26       25.0
# 27       25.0
# 48       25.0
# 49       15.0
# 65       30.0
# 66       45.0
# 67       25.0
# 68       25.0
# 69       10.0
# 70       30.0
# 71       30.0
# 72       25.0
# 73       25.0
# 74       25.0
# 75       45.0
# 76       30.0
# 77       30.0
# 78       30.0
# 79       30.0
# 80       30.0
# 81       25.0
# 82       25.0
# 83       60.0
# 84       30.0
# 100      60.0
# 101      60.0
# 106      30.0
# 107      20.0
# 118      15.0
# 139      30.0
# 140      15.0
# 146      60.0
# 147     120.0
# 148     120.0
# 149      60.0
# 150      60.0
# 156     111.0
# 157    2222.0
# 488      30.0
# 489      30.0
# 490     120.0
# Name: final_time, dtype: float64

# %%
#avg time for a service 
average_time = merged_df['final_time'].mean()
print(f'Average time of a service: {average_time} min')
# Out:
# Average time of a service: 80.49019607843137 min

# %%
plt.figure(figsize=(8, 6))
plt.hist(merged_df['final_time'], bins=20, color='skyblue', edgecolor='black')
plt.axvline(average_time, color='red', linestyle='dashed', linewidth=1)
plt.title('Distribution of Service Times')
plt.xlabel('Time (min)')
plt.ylabel('Frequency')
plt.legend([f'Average Time: {average_time:.2f} min'])
plt.grid(True)
plt.show()

# %%
#the most in demand zones for services

exploded_df = sale_df.explode('zones')
exploded_df = pd.concat([exploded_df.drop(['zones'], axis=1), exploded_df['zones'].apply(pd.Series)], axis=1)

merged_sale_df = pd.merge(exploded_df, zone_df, how='left', left_on='objectId', right_on='_id')
    
zones=merged_sale_df.groupby('name').size().sort_values(ascending=False)
zones
# Out:
# name
# Visage/cou            21
# Corps / Silhouette    13
# Peau                   9
# Cheveux                6
# Zones intimes          3
# Mains                  1
# dtype: int64

# %%
zones_series = pd.Series(zones)

# %%
plt.figure(figsize=(7, 5))
plt.bar(zones_series.index, zones_series.values, color='skyblue')
plt.title('Most In-Demand Zones for Services')
plt.xlabel('Zone')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
category_df = pd.DataFrame(list(db.Category.find()))  
category_df
# Out:
#                 _id                  name             _created_at  \
# 0  EpwZ7ZWHPvU7ldiu          Dermatologie 2024-02-19 07:53:54.886
# 1  tSZdUxmxQvCK1b68   Médecine esthétique 2024-05-01 22:25:52.722
# 2  mc3nmZtfxfCVot5Y  Chirurgie Esthétique 2024-05-01 22:26:25.230
#
#               _updated_at
# 0 2024-05-01 22:26:51.572
# 1 2024-05-01 22:25:52.722
# 2 2024-05-01 22:26:25.230

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   _id          3 non-null      object
#  1   name         3 non-null      object
#  2   _created_at  3 non-null      datetime64[ns]
#  3   _updated_at  3 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), object(2)
# memory usage: 228.0+ bytes
# None
#                          _created_at                    _updated_at
# count                              3                              3
# mean   2024-04-07 17:35:24.279333632  2024-05-01 22:26:23.174666496
# min       2024-02-19 07:53:54.886000     2024-05-01 22:25:52.722000
# 25%    2024-03-26 15:09:53.803999744     2024-05-01 22:26:08.976000
# 50%    2024-05-01 22:25:52.721999872  2024-05-01 22:26:25.230000128
# 75%       2024-05-01 22:26:08.976000  2024-05-01 22:26:38.400999936
# ...

# %%
#avg age for clients
client_df['age'] = pd.to_numeric(client_df['age'], errors='coerce')

client_df = client_df.dropna(subset=['age'])

# Calculate summary statistics
age_summary = client_df['age'].describe()
print("\nAge Summary Statistics:")
print(age_summary)
# Out:
# Age Summary Statistics:
# count    224.000000
# mean      38.424107
# std       10.781713
# min       19.000000
# 25%       35.000000
# 50%       35.000000
# 75%       42.000000
# max       99.000000
# Name: age, dtype: float64

# %%
plt.figure(figsize=(7, 6))
plt.hist(client_df['age'], bins=15, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Number of Clients')
plt.title('Age Distribution of Clients')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
